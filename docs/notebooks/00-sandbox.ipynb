# %%
from sampling_simulator import run_experiment, tokens, logits
import matplotlib.pyplot as plt

temps = [0.1, 0.2, 0.5, 1.0, 1.5, 2.0]
entropies = []

for t in temps:
    out = run_experiment(tokens, logits, temperature=t, n_samples=10000)
    entropies.append(out['entropy'])

plt.plot(temps, entropies, marker='o', label='Entropy')
plt.xlabel('Temperature')
plt.ylabel('Entropy (bits)')
plt.title('How Temperature Affects Distribution Spread')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sampling_simulator import run_experiment, tokens, logits
#       2 import matplotlib.pyplot as plt
#       3
#       4 temps = [0.1, 0.2, 0.5, 1.0, 1.5, 2.0]
#
# ImportError: cannot import name 'tokens' from 'sampling_simulator' (/Users/nchaur590@cable.comcast.com/Programming/ai-parameter-playbook/docs/notebooks/sampling_simulator.py)
